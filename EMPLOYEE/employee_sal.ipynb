# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_hr = pd.read_csv("HR_EMP_TABLE.csv")
df_em.head()
# Out:
#   EMP_ID FIRST_NAME LAST_NAME GENDER                      ROLE        DEPT  \
# 0   E083    Patrick     Voltz      M                   MANAGER  HEALTHCARE
# 1   E052     Dianna    Wilson      F     SENIOR DATA SCIENTIST  HEALTHCARE
# 2   E057    Dorothy    Wilson      F     SENIOR DATA SCIENTIST  HEALTHCARE
# 3   E505       Chad    Wilson      M  ASSOCIATE DATA SCIENTIST  HEALTHCARE
# 4   E260        Roy   Collins      M     SENIOR DATA SCIENTIST      RETAIL
#
#    EXP COUNTRY      CONTINENT MANAGER ID
# 0   15     USA  NORTH AMERICA       E002
# 1    6  CANADA  NORTH AMERICA       E083
# 2    9     USA  NORTH AMERICA       E083
# 3    5  CANADA  NORTH AMERICA       E083
# 4    7   INDIA           ASIA       E583
